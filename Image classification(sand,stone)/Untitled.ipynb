# %%
import os, re, glob
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
  
groups_folder_path = 'C:\\Users\\user\\Desktop\\img\\data\\train\\'
categories = ["sand","stone"]
 
num_classes = len(categories)
  
image_w = 28
image_h = 28
  
X = []
Y = []
  
for idex, categorie in enumerate(categories):
    label = [0 for i in range(num_classes)]
    label[idex] = 1
    image_dir = groups_folder_path + categorie + '/'
  
    for top, dir, f in os.walk(image_dir):
        for filename in f:
            print(image_dir+filename)
            img = cv2.imread(image_dir+filename)
            img = cv2.resize(img, None, fx=image_w/img.shape[1], fy=image_h/img.shape[0])
            X.append(img/256)
            Y.append(label)
 
X = np.array(X)
Y = np.array(Y)
 
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)
xy = (X_train, X_test, Y_train, Y_test)
 
np.save("./img_data.npy", xy)
# Out:
# C:\Users\user\Desktop\img\data\train\sand/0.jpg
# C:\Users\user\Desktop\img\data\train\sand/1.jpg
# C:\Users\user\Desktop\img\data\train\sand/10.jpg
# C:\Users\user\Desktop\img\data\train\sand/11.jpg
# C:\Users\user\Desktop\img\data\train\sand/12.jpg
# C:\Users\user\Desktop\img\data\train\sand/13.jpg
# C:\Users\user\Desktop\img\data\train\sand/14.jpg
# C:\Users\user\Desktop\img\data\train\sand/15.jpg
# C:\Users\user\Desktop\img\data\train\sand/16.jpg
# C:\Users\user\Desktop\img\data\train\sand/17.jpg
# C:\Users\user\Desktop\img\data\train\sand/18.jpg
# C:\Users\user\Desktop\img\data\train\sand/19.jpg
# C:\Users\user\Desktop\img\data\train\sand/2.jpg
# C:\Users\user\Desktop\img\data\train\sand/20.jpg
# C:\Users\user\Desktop\img\data\train\sand/21.jpg
# C:\Users\user\Desktop\img\data\train\sand/22.jpg
# C:\Users\user\Desktop\img\data\train\sand/23.jpg
# C:\Users\user\Desktop\img\data\train\sand/24.jpg
# C:\Users\user\Desktop\img\data\train\sand/25.jpg
# C:\Users\user\Desktop\img\data\train\sand/26.jpg
# C:\Users\user\Desktop\img\data\train\sand/27.jpg
# C:\Users\user\Desktop\img\data\train\sand/28.jpg
# C:\Users\user\Desktop\img\data\train\sand/29.jpg
# C:\Users\user\Desktop\img\data\train\sand/3.jpg
# C:\Users\user\Desktop\img\data\train\sand/30.jpg
# C:\Users\user\Desktop\img\data\train\sand/31.jpg
# C:\Users\user\Desktop\img\data\train\sand/32.jpg
# C:\Users\user\Desktop\img\data\train\sand/33.jpg
# C:\Users\user\Desktop\img\data\train\sand/34.jpg
# C:\Users\user\Desktop\img\data\train\sand/35.jpg
# C:\Users\user\Desktop\img\data\train\sand/36.jpg
# C:\Users\user\Desktop\img\data\train\sand/37.jpg
# C:\Users\user\Desktop\img\data\train\sand/4.jpg
# C:\Users\user\Desktop\img\data\train\sand/5.jpg
# C:\Users\user\Desktop\img\data\train\sand/6.jpg
# C:\Users\user\Desktop\img\data\train\sand/7.jpg
# C:\Users\user\Desktop\img\data\train\sand/8.jpg
# C:\Users\user\Desktop\img\data\train\sand/9.jpg
# C:\Users\user\Desktop\img\data\train\stone/0.jpg
# C:\Users\user\Desktop\img\data\train\stone/1.jpg
# C:\Users\user\Desktop\img\data\train\stone/10.jpg
# C:\Users\user\Desktop\img\data\train\stone/11.jpg
# C:\Users\user\Desktop\img\data\train\stone/12.jpg
# C:\Users\user\Desktop\img\data\train\stone/13.jpg
# C:\Users\user\Desktop\img\data\train\stone/14.jpg
# C:\Users\user\Desktop\img\data\train\stone/16.jpg
# C:\Users\user\Desktop\img\data\train\stone/17.jpg
# C:\Users\user\Desktop\img\data\train\stone/18.jpg
# C:\Users\user\Desktop\img\data\train\stone/19.jpg
# C:\Users\user\Desktop\img\data\train\stone/2.jpg
# C:\Users\user\Desktop\img\data\train\stone/20.jpg
# C:\Users\user\Desktop\img\data\train\stone/21.jpg
# C:\Users\user\Desktop\img\data\train\stone/22.jpg
# C:\Users\user\Desktop\img\data\train\stone/23.jpg
# C:\Users\user\Desktop\img\data\train\stone/24.jpg
# C:\Users\user\Desktop\img\data\train\stone/25.jpg
# C:\Users\user\Desktop\img\data\train\stone/26.jpg
# C:\Users\user\Desktop\img\data\train\stone/27.jpg
# C:\Users\user\Desktop\img\data\train\stone/28.jpg
# C:\Users\user\Desktop\img\data\train\stone/29.jpg
# C:\Users\user\Desktop\img\data\train\stone/3.jpg
# C:\Users\user\Desktop\img\data\train\stone/30.jpg
# C:\Users\user\Desktop\img\data\train\stone/31.jpg
# C:\Users\user\Desktop\img\data\train\stone/32.jpg
# C:\Users\user\Desktop\img\data\train\stone/33.jpg
# C:\Users\user\Desktop\img\data\train\stone/34.jpg
# C:\Users\user\Desktop\img\data\train\stone/35.jpg
# C:\Users\user\Desktop\img\data\train\stone/4.jpg
# C:\Users\user\Desktop\img\data\train\stone/5.jpg
# C:\Users\user\Desktop\img\data\train\stone/6.jpg
# C:\Users\user\Desktop\img\data\train\stone/7.jpg
# C:\Users\user\Desktop\img\data\train\stone/8.jpg
# C:\Users\user\Desktop\img\data\train\stone/9.jpg

# %%
from keras.models import Sequential
from keras.layers import Dropout, Activation, Dense
from keras.layers import Flatten, Convolution2D, MaxPooling2D
from keras.models import load_model
import cv2
 
X_train, X_test, Y_train, Y_test = np.load('./img_data.npy')
 
model = Sequential()
model = Sequential()
model.add(Convolution2D(16, 3, 3, border_mode='same', activation='relu',
                        input_shape=X_train.shape[1:]))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
  
model.add(Convolution2D(64, 3, 3,  activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
 
model.add(Convolution2D(64, 3, 3))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
  
model.add(Flatten())
model.add(Dense(256, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes,activation = 'softmax'))
  
model.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])
model.fit(X_train, Y_train, batch_size=32, nb_epoch=100)
 
model.save('Gersang.h5')
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), activation="relu", input_shape=(28, 28, 3..., padding="same")`
#   if sys.path[0] == '':
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
#   app.launch_new_instance()
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:30: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.6944 - accuracy: 0.5741
# Epoch 2/100
# 54/54 [==============================] - 0s 739us/step - loss: 0.7758 - accuracy: 0.4444
# Epoch 3/100
# 54/54 [==============================] - 0s 646us/step - loss: 0.7262 - accuracy: 0.4815
# Epoch 4/100
# 54/54 [==============================] - 0s 646us/step - loss: 0.7473 - accuracy: 0.4444
# Epoch 5/100
# 54/54 [==============================] - 0s 628us/step - loss: 0.7032 - accuracy: 0.4815
# Epoch 6/100
# 54/54 [==============================] - 0s 665us/step - loss: 0.6927 - accuracy: 0.5556
# Epoch 7/100
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='loss', patience=100)
 
# Learning and save models
model.fit(X_train, Y_train, validation_split=0.1, epochs=3500, batch_size=10, verbose=0, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 00001: loss improved from inf to 0.12980, saving model to Gersang.h5
#
# Epoch 00002: loss did not improve from 0.12980
#
# Epoch 00003: loss improved from 0.12980 to 0.08677, saving model to Gersang.h5
#
# Epoch 00004: loss improved from 0.08677 to 0.02501, saving model to Gersang.h5
#
# Epoch 00005: loss did not improve from 0.02501
#
# Epoch 00006: loss did not improve from 0.02501
#
# Epoch 00007: loss did not improve from 0.02501
#
# Epoch 00008: loss did not improve from 0.02501
#
# Epoch 00009: loss did not improve from 0.02501
#
# Epoch 00010: loss did not improve from 0.02501
#
# Epoch 00011: loss did not improve from 0.02501
#
# Epoch 00012: loss improved from 0.02501 to 0.01255, saving model to Gersang.h5
#
# Epoch 00013: loss improved from 0.01255 to 0.00909, saving model to Gersang.h5
#
# Epoch 00014: loss improved from 0.00909 to 0.00537, saving model to Gersang.h5
#
# Epoch 00015: loss did not improve from 0.00537
#
# Epoch 00016: loss did not improve from 0.00537
#
# Epoch 00017: loss did not improve from 0.00537
#
# Epoch 00018: loss did not improve from 0.00537
#
# Epoch 00019: loss did not improve from 0.00537
#
# Epoch 00020: loss did not improve from 0.00537
#
# Epoch 00021: loss did not improve from 0.00537
#
# Epoch 00022: loss improved from 0.00537 to 0.00494, saving model to Gersang.h5
#
# Epoch 00023: loss did not improve from 0.00494
#
# Epoch 00024: loss did not improve from 0.00494
#
# Epoch 00025: loss improved from 0.00494 to 0.00468, saving model to Gersang.h5
#
# Epoch 00026: loss did not improve from 0.00468
#
# Epoch 00027: loss did not improve from 0.00468
#
# Epoch 00028: loss did not improve from 0.00468
#
# Epoch 00029: loss improved from 0.00468 to 0.00326, saving model to Gersang.h5
#
# Epoch 00030: loss did not improve from 0.00326
#
# Epoch 00031: loss did not improve from 0.00326
#
# Epoch 00032: loss improved from 0.00326 to 0.00284, saving model to Gersang.h5
#
# Epoch 00033: loss improved from 0.00284 to 0.00183, saving model to Gersang.h5
#
# Epoch 00034: loss did not improve from 0.00183
#
# Epoch 00035: loss improved from 0.00183 to 0.00178, saving model to Gersang.h5
#
# Epoch 00036: loss did not improve from 0.00178
#
# Epoch 00037: loss improved from 0.00178 to 0.00039, saving model to Gersang.h5
#
# Epoch 00038: loss did not improve from 0.00039
#
# Epoch 00039: loss did not improve from 0.00039
#
# Epoch 00040: loss did not improve from 0.00039
#
# Epoch 00041: loss did not improve from 0.00039
#
# Epoch 00042: loss did not improve from 0.00039
#
# Epoch 00043: loss did not improve from 0.00039
#
# Epoch 00044: loss did not improve from 0.00039
#
# Epoch 00045: loss did not improve from 0.00039
#
# Epoch 00046: loss did not improve from 0.00039
#
# Epoch 00047: loss did not improve from 0.00039
#
# Epoch 00048: loss did not improve from 0.00039
#
# Epoch 00049: loss did not improve from 0.00039
#
# Epoch 00050: loss did not improve from 0.00039
#
# Epoch 00051: loss did not improve from 0.00039
#
# Epoch 00052: loss did not improve from 0.00039
#
# Epoch 00053: loss improved from 0.00039 to 0.00022, saving model to Gersang.h5
#
# Epoch 00054: loss did not improve from 0.00022
#
# Epoch 00055: loss did not improve from 0.00022
#
# Epoch 00056: loss did not improve from 0.00022
#
# Epoch 00057: loss did not improve from 0.00022
#
# Epoch 00058: loss did not improve from 0.00022
#
# Epoch 00059: loss did not improve from 0.00022
#
# Epoch 00060: loss did not improve from 0.00022
#
# Epoch 00061: loss did not improve from 0.00022
#
# Epoch 00062: loss improved from 0.00022 to 0.00013, saving model to Gersang.h5
#
# Epoch 00063: loss did not improve from 0.00013
#
# Epoch 00064: loss did not improve from 0.00013
#
# Epoch 00065: loss did not improve from 0.00013
#
# Epoch 00066: loss did not improve from 0.00013
#
# Epoch 00067: loss did not improve from 0.00013
#
# Epoch 00068: loss did not improve from 0.00013
#
# Epoch 00069: loss did not improve from 0.00013
#
# Epoch 00070: loss did not improve from 0.00013
#
# Epoch 00071: loss did not improve from 0.00013
#
# Epoch 00072: loss did not improve from 0.00013
#
# Epoch 00073: loss did not improve from 0.00013
#
# Epoch 00074: loss did not improve from 0.00013
#
# Epoch 00075: loss did not improve from 0.00013
#
# Epoch 00076: loss did not improve from 0.00013
#
# Epoch 00077: loss did not improve from 0.00013
#
# Epoch 00078: loss did not improve from 0.00013
#
# Epoch 00079: loss did not improve from 0.00013
#
# Epoch 00080: loss did not improve from 0.00013
#
# Epoch 00081: loss did not improve from 0.00013
#
# Epoch 00082: loss did not improve from 0.00013
#
# Epoch 00083: loss did not improve from 0.00013
#
# Epoch 00084: loss did not improve from 0.00013
#
# Epoch 00085: loss did not improve from 0.00013
#
# Epoch 00086: loss did not improve from 0.00013
#
# Epoch 00087: loss did not improve from 0.00013
#
# Epoch 00088: loss did not improve from 0.00013
#
# Epoch 00089: loss did not improve from 0.00013
#
# Epoch 00090: loss did not improve from 0.00013
#
# Epoch 00091: loss did not improve from 0.00013
#
# Epoch 00092: loss did not improve from 0.00013
#
# Epoch 00093: loss did not improve from 0.00013
#
# Epoch 00094: loss did not improve from 0.00013
#
# Epoch 00095: loss did not improve from 0.00013
#
# Epoch 00096: loss did not improve from 0.00013
#
# Epoch 00097: loss did not improve from 0.00013
#
# Epoch 00098: loss did not improve from 0.00013
#
# Epoch 00099: loss did not improve from 0.00013
#
# Epoch 00100: loss did not improve from 0.00013
#
# Epoch 00101: loss did not improve from 0.00013
#
# Epoch 00102: loss did not improve from 0.00013
#
# Epoch 00103: loss did not improve from 0.00013
#
# Epoch 00104: loss did not improve from 0.00013
#
# Epoch 00105: loss did not improve from 0.00013
#
# Epoch 00106: loss did not improve from 0.00013
#
# Epoch 00107: loss did not improve from 0.00013
#
# Epoch 00108: loss did not improve from 0.00013
#
# Epoch 00109: loss did not improve from 0.00013
#
# Epoch 00110: loss did not improve from 0.00013
#
# Epoch 00111: loss did not improve from 0.00013
#
# Epoch 00112: loss did not improve from 0.00013
#
# Epoch 00113: loss did not improve from 0.00013
#
# Epoch 00114: loss did not improve from 0.00013
#
# Epoch 00115: loss did not improve from 0.00013
#
# Epoch 00116: loss did not improve from 0.00013
#
# Epoch 00117: loss did not improve from 0.00013
#
# Epoch 00118: loss did not improve from 0.00013
#
# Epoch 00119: loss did not improve from 0.00013
#
# Epoch 00120: loss did not improve from 0.00013
#
# Epoch 00121: loss did not improve from 0.00013
#
# Epoch 00122: loss did not improve from 0.00013
#
# Epoch 00123: loss did not improve from 0.00013
#
# Epoch 00124: loss did not improve from 0.00013
#
# Epoch 00125: loss did not improve from 0.00013
#
# Epoch 00126: loss did not improve from 0.00013
#
# Epoch 00127: loss did not improve from 0.00013
#
# Epoch 00128: loss did not improve from 0.00013
#
# Epoch 00129: loss did not improve from 0.00013
#
# Epoch 00130: loss did not improve from 0.00013
#
# Epoch 00131: loss did not improve from 0.00013
#
# Epoch 00132: loss did not improve from 0.00013
#
# Epoch 00133: loss did not improve from 0.00013
#
# Epoch 00134: loss did not improve from 0.00013
#
# Epoch 00135: loss did not improve from 0.00013
#
# Epoch 00136: loss did not improve from 0.00013
#
# Epoch 00137: loss did not improve from 0.00013
#
# Epoch 00138: loss did not improve from 0.00013
#
# Epoch 00139: loss did not improve from 0.00013
#
# Epoch 00140: loss did not improve from 0.00013
#
# Epoch 00141: loss did not improve from 0.00013
#
# Epoch 00142: loss did not improve from 0.00013
#
# Epoch 00143: loss did not improve from 0.00013
#
# Epoch 00144: loss did not improve from 0.00013
#
# Epoch 00145: loss did not improve from 0.00013
#
# Epoch 00146: loss did not improve from 0.00013
#
# Epoch 00147: loss did not improve from 0.00013
#
# Epoch 00148: loss did not improve from 0.00013
#
# Epoch 00149: loss did not improve from 0.00013
#
# Epoch 00150: loss did not improve from 0.00013
#
# Epoch 00151: loss did not improve from 0.00013
#
# Epoch 00152: loss did not improve from 0.00013
#
# Epoch 00153: loss did not improve from 0.00013
#
# Epoch 00154: loss did not improve from 0.00013
#
# Epoch 00155: loss did not improve from 0.00013
#
# Epoch 00156: loss did not improve from 0.00013
#
# Epoch 00157: loss did not improve from 0.00013
#
# Epoch 00158: loss did not improve from 0.00013
#
# Epoch 00159: loss did not improve from 0.00013
#
# Epoch 00160: loss did not improve from 0.00013
#
# Epoch 00161: loss did not improve from 0.00013
# Epoch 00162: loss did not improve from 0.00013

# %%
import os, re, glob
import cv2
import numpy as np
import shutil
from numpy import argmax
from keras.models import load_model

def Dataization(img_path):
    image_w = 28
    image_h = 28
    img = cv2.imread(img_path)
    img = cv2.resize(img, None, fx=image_w/img.shape[1], fy=image_h/img.shape[0])
    return (img/256)
 
src = []
name = []
test = []
image_dir = "C:\\Users\\user\\Desktop\\img\data\\test\\"
for file in os.listdir(image_dir):
    if (file.find('.jpg') is not -1):       
        src.append(image_dir + file)
        name.append(file)
        test.append(Dataization(image_dir + file))
 
 
test = np.array(test)
model = load_model('Gersang.h5')
predict = model.predict_classes(test)
 
for i in range(len(test)):
    print(name[i] + " : Predict : "+ str(categories[predict[i]]))
# Out:
# 2.jpg : Predict : stone
# 20.jpg : Predict : stone
# 32.jpg : Predict : stone
# 35.jpg : Predict : sand
# 37.jpg : Predict : sand
# 4.jpg : Predict : stone
# 9.jpg : Predict : stone
